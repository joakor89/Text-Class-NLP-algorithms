# %% [markdown]
# # Training a Hidden Markovian Model (HMM)

# %% [markdown]
# ## Spanish Corpus:
#
# * AnCora | Github: https://github.com/UniversalDependencies/UD_Spanish-AnCora
#
# * I've used conllu parser to read the corpus: https://pypi.org/project/conllu/
#
# * Universal Tag POS (Documentation): https://universaldependencies.org/u/pos/

# %%
#@title Previous Dependencies
# !pip install conllu
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting conllu
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.5.2
# Cloning into 'UD_Spanish-AnCora'...
# remote: Enumerating objects: 1054, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 1054 (delta 53), reused 70 (delta 53), pack-reused 984
# Receiving objects: 100% (1054/1054), 388.11 MiB | 24.44 MiB/s, done.
# Resolving deltas: 100% (746/746), done.

# %%
#@title Reading AnCora Corpus
from conllu import parse_incr
# Void List 
wordList = []
# File Selection & Reading Permission
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")
for tokenlist in parse_incr(data_file):
    print(tokenlist.serialize())
# Out:
# Streaming output truncated to the last 5000 lines.
# 22	en	en	ADP	sps00	_	23	case	23:case	_
# 23	multitud	multitud	NOUN	ncfs000	Gender=Fem|Number=Sing	18	obl	18:obl	Entity=(CESSCASTAA200004128873c18--1-gstype:gen
# 24	de	de	ADP	sps00	_	25	case	25:case	_
# 25	vehículos	vehículo	NOUN	ncmp000	Gender=Masc|Number=Plur	23	nmod	23:nmod	Entity=(CESSCASTAA200004128873c11--1-gstype:gen
# 26	que	que	PRON	pr0cn000	PronType=Int,Rel	28	nsubj	28:nsubj	Entity=(CESSCASTAA200004128873c11--1-CorefType:ident,gstype:gen)
# 27	están	estar	AUX	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	28	cop	28:cop	_
# 28	preparados	preparado	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	25	acl	25:acl	_
# 29	para	para	ADP	sps00	_	30	mark	30:mark	_
# 30	consumir	consumir	VERB	vmn0000	VerbForm=Inf	28	advcl	28:advcl	_
# 31	indistintamente	indistintamente	ADV	rg	_	32	advmod	32:advmod	Entity=(CESSCASTAA200004128873s4.sn.78--2-gstype:gen
# 32	combustible	combustible	NOUN	ncms000	Gender=Masc|Number=Sing	30	obj	30:obj	ClusterId[1]=CESS-CAST-AA-20000412-8873-s4.sn.78|ClusterType[1]=Gen|MentionSpan[1]=31-37|ClusterId[2]=CESS-CAST-AA-20000412-8873-s4.sn.82|ClusterType[2]=Gen|MentionSpan[2]=32-37|Entity=(CESSCASTAA200004128873s4.sn.82--1-gstype:gen
# 33	con	con	ADP	sps00	_	34	case	34:case	_
# 34	plomo	plomo	NOUN	ncms000	Gender=Masc|Number=Sing	32	nmod	32:nmod	Entity=(CESSCASTAA200004128873c9--1-CorefType:ident,gstype:gen)
# 35	o	o	CCONJ	cc	_	37	cc	37:cc	_
# 36	sin	sin	ADP	sps00	_	37	case	37:case	_
# 37	plomo	plomo	NOUN	ncms000	Gender=Masc|Number=Sing	34	conj	34:conj	SpaceAfter=No|Entity=CESSCASTAA200004128873s4.sn.82)CESSCASTAA200004128873s4.sn.78)CESSCASTAA200004128873c11)CESSCASTAA200004128873c18)CESSCASTAA200004128873c10)
# 38	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000412-8873-s5
# # text = Una buena parte de este parque, explicó el ministro, sigue utilizando gasolina de 97 octanos cuando puede emplear la de 95 sin riesgo alguno.
# 1	Una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	3	det	3:det	Entity=(CESSCASTAA200004128873c12--3-gstype:gen
# 2	buena	buen	ADJ	aq0fs0	Gender=Fem|Number=Sing	1	amod	1:amod	_
# 3	parte	parte	NOUN	ncfs000	Gender=Fem|Number=Sing	12	nsubj	12:nsubj	_
# 4	de	de	ADP	sps00	_	6	case	6:case	_
# 5	este	este	DET	dd0ms0	Gender=Masc|Number=Sing|PronType=Dem	6	det	6:det	Entity=(CESSCASTAA200004128873c18--2-CorefType:ident,gstype:gen
# 6	parque	parque	NOUN	ncms000	Gender=Masc|Number=Sing	3	nmod	3:nmod	SpaceAfter=No|Entity=CESSCASTAA200004128873c18)CESSCASTAA200004128873c12)
# 7	,	,	PUNCT	fc	PunctType=Comm	8	punct	8:punct	_
# 8	explicó	explicar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	13	parataxis	13:parataxis	_
# 9	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	10	det	10:det	Entity=(CESSCASTAA200004128873c3-person-2-CorefType:ident,gstype:spec
# 10	ministro	ministro	NOUN	ncms000	Gender=Masc|Number=Sing	8	nsubj	8:nsubj	SpaceAfter=No|Entity=CESSCASTAA200004128873c3)
# 11	,	,	PUNCT	fc	PunctType=Comm	8	punct	8:punct	_
# 12	sigue	seguir	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 13	utilizando	utilizar	VERB	vmg0000	VerbForm=Ger	12	xcomp	12:xcomp	_
# 14	gasolina	gasolina	NOUN	ncfs000	Gender=Fem|Number=Sing	13	obj	13:obj	Entity=(CESSCASTAA200004128873s5.sn.31--1-gstype:gen
# 15	de	de	ADP	sps00	_	17	case	17:case	_
# 16	97	97	NUM	_	NumForm=Digit|NumType=Card	17	nummod	17:nummod	Entity=(CESSCASTAA200004128873s5.sn.37-number-2-gstype:spec
# 17	octanos	octano	NOUN	ncmp000	Gender=Masc|Number=Plur	14	nmod	14:nmod	Entity=CESSCASTAA200004128873s5.sn.37)CESSCASTAA200004128873s5.sn.31)
# 18	cuando	cuando	SCONJ	cs	_	20	mark	20:mark	_
# 18.1	_	_	PRON	p	_	_	_	20:nsubj	Entity=(CESSCASTAA200004128873c12--1-CorefType:ident,gstype:gen)
# 19	puede	poder	AUX	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	20	aux	20:aux	_
# 20	emplear	emplear	VERB	vmn0000	VerbForm=Inf	13	advcl	13:advcl	_
# 21	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	20	det	20:det	Entity=(CESSCASTAA200004128873c8--1-CorefType:ident,gstype:gen,HomoDD
# 22	de	de	ADP	sps00	_	21	case	21:case	_
# 23	95	95	NUM	_	NumForm=Digit|NumType=Card	21	obj	21:obj	ClusterId[1]=CESS-CAST-AA-20000412-8873-c8|ClusterType[1]=Gen|MentionSpan[1]=21-23|MentionMisc[1]=HomoDD,CorefType:ident|ClusterId[2]=CESS-CAST-AA-20000412-8873-s5.sn.57|ClusterType[2]=Spec.number|MentionSpan[2]=23|Entity=(CESSCASTAA200004128873s5.sn.57-number-1-gstype:spec)CESSCASTAA200004128873c8)
# 24	sin	sin	ADP	sps00	_	25	case	25:case	_
# 25	riesgo	riesgo	NOUN	ncms000	Gender=Masc|Number=Sing	20	obl	20:obl	Entity=(CESSCASTAA200004128873s5.sn.63--1-gstype:gen
# 26	alguno	alguno	ADJ	aq0ms0	Gender=Masc|Number=Sing	25	amod	25:amod	SpaceAfter=No|Entity=CESSCASTAA200004128873s5.sn.63)
# 27	.	.	PUNCT	fp	PunctType=Peri	12	punct	12:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000412-8873-s6
# # text = Según el Real Decreto aprobado el pasado 24 de marzo por el Consejo de Ministros, estas gasolinas con plomo deberán cumplir, en todo caso, las especificaciones vigentes.
# 1	Según	según	ADP	sps00	_	3	case	3:case	_
# 2	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	3	det	3:det	Entity=(CESSCASTAA200004128873c1-other-2-CorefType:ident,gstype:spec
# 3	Real	Real	PROPN	np00000	_	22	obl	22:obl	MWE=Real_Decreto|MWEPOS=PROPN
# 4	Decreto	Decreto	PROPN	_	_	3	flat	3:flat	_
# 5	aprobado	aprobado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	3	amod	3:amod	_
# 6	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	8	det	8:det	Entity=(CESSCASTAA200004128873s6.sn.13-time-3-gstype:spec
# 7	pasado	pasado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	8	amod	8:amod	_
# 8	24	24	NUM	_	NumForm=Digit|NumType=Card	5	obl	5:obl	MWE=24_de_marzo|MWEPOS=NOUN
# 9	de	de	ADP	_	_	10	case	10:case	_
# 10	marzo	marzo	NOUN	_	_	8	compound	8:compound	Entity=CESSCASTAA200004128873s6.sn.13)
# 11	por	por	ADP	sps00	_	13	case	13:case	_
# 12	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	13	det	13:det	Entity=(CESSCASTAA200004128873s6.sn.24-organization-2-gstype:spec
# 13	Consejo	Consejo	PROPN	np00000	_	5	obj	5:obj	MWE=Consejo_de_Ministros|MWEPOS=PROPN
# 14	de	de	ADP	_	_	15	case	15:case	_
# 15	Ministros	Ministros	PROPN	_	_	13	flat	13:flat	SpaceAfter=No|Entity=CESSCASTAA200004128873s6.sn.24)CESSCASTAA200004128873c1)
# 16	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	_
# 17	estas	este	DET	dd0fp0	Gender=Fem|Number=Plur|PronType=Dem	18	det	18:det	Entity=(CESSCASTAA200004128873c2--2-CorefType:ident,gstype:gen
# 18	gasolinas	gasolina	NOUN	ncfp000	Gender=Fem|Number=Plur	22	nsubj	22:nsubj	_
# 19	con	con	ADP	sps00	_	20	case	20:case	_
# 20	plomo	plomo	NOUN	ncms000	Gender=Masc|Number=Sing	18	nmod	18:nmod	Entity=(CESSCASTAA200004128873c9--1-CorefType:ident,gstype:gen)CESSCASTAA200004128873c2)
# 21	deberán	deber	AUX	vmif3p0	Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin	22	aux	22:aux	_
# 22	cumplir	cumplir	VERB	vmn0000	VerbForm=Inf	0	root	0:root	SpaceAfter=No
# 23	,	,	PUNCT	fc	PunctType=Comm	24	punct	24:punct	_
# 24	en	en	ADP	rg	_	22	advmod	22:advmod	MWE=en_todo_caso|MWEPOS=ADV
# 25	todo	todo	PRON	_	Gender=Masc|Number=Sing|PronType=Tot	24	fixed	24:fixed	_
# 26	caso	caso	NOUN	_	_	24	fixed	24:fixed	SpaceAfter=No
# 27	,	,	PUNCT	fc	PunctType=Comm	24	punct	24:punct	_
# 28	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	29	det	29:det	Entity=(CESSCASTAA200004128873s6.sn.50--2-gstype:gen,HomoDD
# 29	especificaciones	especificación	NOUN	ncfp000	Gender=Fem|Number=Plur	22	obj	22:obj	_
# 30	vigentes	vigente	ADJ	aq0cp0	Number=Plur	29	amod	29:amod	SpaceAfter=No|Entity=CESSCASTAA200004128873s6.sn.50)
# 31	.	.	PUNCT	fp	PunctType=Peri	22	punct	22:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000412-8873-s7
# # text = Una directiva comunitaria de 13 de octubre de 1998 establecía la prohibición de comercializar gasolinas con plomo a partir de enero de 2000, pero contemplaba la posibilidad de autorizar a un estado miembro, previa solicitud a la Comisión Europea, a continuar comercializando este combustible hasta el 1 de enero de 2005.
# 1	Una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200004128873c13--2-gstype:gen
# 2	directiva	directiva	NOUN	ncfs000	Gender=Fem|Number=Sing	10	nsubj	10:nsubj	_
# 3	comunitaria	comunitario	ADJ	aq0fs0	Gender=Fem|Number=Sing	2	amod	2:amod	_
# 4	de	de	ADP	sps00	_	5	case	5:case	_
# 5	13	13	NUM	_	NumForm=Digit|NumType=Card	2	nmod	2:nmod	MWE=13_de_octubre_de_1998|MWEPOS=NOUN|Entity=(CESSCASTAA200004128873s7.sn.14-time-1-gstype:spec
# 6	de	de	ADP	_	_	7	case	7:case	_
# 7	octubre	octubre	NOUN	_	_	5	compound	5:compound	_
# 8	de	de	ADP	_	_	9	case	9:case	_
# 9	1998	1998	NUM	_	NumForm=Digit|NumType=Card	5	compound	5:compound	Entity=CESSCASTAA200004128873s7.sn.14)CESSCASTAA200004128873c13)
# 10	establecía	establecer	VERB	vmii3s0	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	0	root	0:root	_
# 11	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	12	det	12:det	Entity=(CESSCASTAA200004128873c17--2-gstype:gen,HomoDD
# 12	prohibición	prohibición	NOUN	ncfs000	Gender=Fem|Number=Sing	10	obj	10:obj	_
# 13	de	de	ADP	sps00	_	14	mark	14:mark	_
# 14	comercializar	comercializar	VERB	vmn0000	VerbForm=Inf	12	acl	12:acl	_
# 15	gasolinas	gasolina	NOUN	ncfp000	Gender=Fem|Number=Plur	14	obj	14:obj	Entity=(CESSCASTAA200004128873c2--1-CorefType:ident,gstype:gen
# 16	con	con	ADP	sps00	_	17	case	17:case	_
# 17	plomo	plomo	NOUN	ncms000	Gender=Masc|Number=Sing	15	nmod	15:nmod	Entity=(CESSCASTAA200004128873c9--1-CorefType:ident,gstype:gen)CESSCASTAA200004128873c2)CESSCASTAA200004128873c17)
# 18	a	a	ADP	sps00	_	21	case	21:case	MWE=a_partir_de|MWEPOS=ADP
# 19	partir	partir	NOUN	_	_	18	fixed	18:fixed	_
# 20	de	de	ADP	_	_	18	fixed	18:fixed	_
# 21	enero	enero	NOUN	_	_	10	obl	10:obl	MWE=enero_de_2000|MWEPOS=NOUN|Entity=(CESSCASTAA200004128873s7.sn.42-time-1-gstype:spec
# 22	de	de	ADP	_	_	23	case	23:case	_
# 23	2000	2000	NUM	_	NumForm=Digit|NumType=Card	21	compound	21:compound	SpaceAfter=No|Entity=CESSCASTAA200004128873s7.sn.42)
# 24	,	,	PUNCT	fc	PunctType=Comm	26	punct	26:punct	_
# 25	pero	pero	CCONJ	cc	_	26	cc	26:cc	_
# 25.1	_	_	PRON	p	_	_	_	26:nsubj	Entity=(CESSCASTAA200004128873c13--1-CorefType:ident,gstype:gen)
# 26	contemplaba	contemplar	VERB	vmii3s0	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	10	conj	10:conj	_
# 27	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	28	det	28:det	Entity=(CESSCASTAA200004128873s7.sn.52--2-gstype:gen,HomoDD
# 28	posibilidad	posibilidad	NOUN	ncfs000	Gender=Fem|Number=Sing	26	obj	26:obj	_
# 29	de	de	ADP	sps00	_	30	mark	30:mark	_
# 30	autorizar	autorizar	VERB	vmn0000	VerbForm=Inf	28	acl	28:acl	_
# 31	a	a	ADP	sps00	_	33	case	33:case	_
# 32	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	33	det	33:det	Entity=(CESSCASTAA200004128873s7.sn.66--2-gstype:gen
# 33	estado	estado	NOUN	ncms000	Gender=Masc|Number=Sing	30	iobj	30:iobj	_
# 34	miembro	miembro	NOUN	ncms000	Gender=Masc|Number=Sing	33	nmod	33:nmod	SpaceAfter=No|Entity=CESSCASTAA200004128873s7.sn.66)
# 35	,	,	PUNCT	fc	PunctType=Comm	37	punct	37:punct	Entity=(CESSCASTAA200004128873s7.sn.74--3-gstype:gen
# 36	previa	previo	ADJ	aq0fs0	Gender=Fem|Number=Sing	37	amod	37:amod	_
# 37	solicitud	solicitud	NOUN	ncfs000	Gender=Fem|Number=Sing	30	obl	30:obl	_
# 38	a	a	ADP	sps00	_	40	case	40:case	_
# 39	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	40	det	40:det	Entity=(CESSCASTAA200004128873c14-organization-2-gstype:spec
# 40	Comisión	Comisión	PROPN	np00000	_	37	nmod	37:nmod	MWE=Comisión_Europea|MWEPOS=PROPN
# 41	Europea	Europea	PROPN	_	_	40	flat	40:flat	SpaceAfter=No|Entity=CESSCASTAA200004128873c14)
# 42	,	,	PUNCT	fc	PunctType=Comm	37	punct	37:punct	Entity=CESSCASTAA200004128873s7.sn.74)
# 43	a	a	ADP	sps00	_	44	mark	44:mark	_
# 44	continuar	continuar	VERB	vmn0000	VerbForm=Inf	30	ccomp	30:ccomp	_
# 45	comercializando	comercializar	VERB	vmg0000	VerbForm=Ger	44	xcomp	44:xcomp	_
# 46	este	este	DET	dd0ms0	Gender=Masc|Number=Sing|PronType=Dem	47	det	47:det	Entity=(CESSCASTAA200004128873c2--2-CorefType:ident,gstype:gen
# 47	combustible	combustible	ADJ	aq0cs0	Number=Sing	45	obj	45:obj	Entity=CESSCASTAA200004128873c2)
# 48	hasta	hasta	ADP	sps00	_	50	case	50:case	_
# 49	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	50	det	50:det	Entity=(CESSCASTAA200004128873c15-time-2-gstype:spec
# 50	1	1	NUM	_	NumForm=Digit|NumType=Card	44	obl	44:obl	MWE=1_de_enero_de_2005|MWEPOS=NOUN
# 51	de	de	ADP	_	_	52	case	52:case	_
# 52	enero	enero	NOUN	_	_	50	compound	50:compound	_
# 53	de	de	ADP	_	_	54	case	54:case	_
# 54	2005	2005	NUM	_	NumForm=Digit|NumType=Card	50	compound	50:compound	SpaceAfter=No|Entity=CESSCASTAA200004128873c15)CESSCASTAA200004128873s7.sn.52)
# 55	.	.	PUNCT	fp	PunctType=Peri	10	punct	10:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000412-8873-s8
# # text = Un Real Decreto de 12 de noviembre de 1999 traspuso parcialmente esta directiva, que contenía, asi mismo, especificaciones relativas a la calidad de la gasolina y del gasóleo de automoción.
# 1	Un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200004128873s8.sn.2--2-gstype:gen
# 2	Real	Real	PROPN	np00000	_	10	nsubj	10:nsubj	MWE=Real_Decreto|MWEPOS=PROPN
# 3	Decreto	Decreto	PROPN	_	_	2	flat	2:flat	_
# 4	de	de	ADP	sps00	_	5	case	5:case	_
# 5	12	12	NUM	_	NumForm=Digit|NumType=Card	2	nmod	2:nmod	MWE=12_de_noviembre_de_1999|MWEPOS=NOUN|Entity=(CESSCASTAA200004128873s8.sn.10-time-1-gstype:spec
# 6	de	de	ADP	_	_	7	case	7:case	_
# 7	noviembre	noviembre	NOUN	_	_	5	compound	5:compound	_
# 8	de	de	ADP	_	_	9	case	9:case	_
# 9	1999	1999	NUM	_	NumForm=Digit|NumType=Card	5	compound	5:compound	Entity=CESSCASTAA200004128873s8.sn.10)CESSCASTAA200004128873s8.sn.2)
# 10	traspuso	trasponer	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 11	parcialmente	parcialmente	ADV	rg	_	13	advmod	13:advmod	Entity=(CESSCASTAA200004128873s8.sn.15--3-gstype:gen
# 12	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	13	det	13:det	Entity=(CESSCASTAA200004128873c13--2-CorefType:ident,gstype:gen
# 13	directiva	directiva	NOUN	ncfs000	Gender=Fem|Number=Sing	10	obj	10:obj	SpaceAfter=No|ClusterId[1]=CESS-CAST-AA-20000412-8873-s8.sn.15|ClusterType[1]=Gen|MentionSpan[1]=11-34|ClusterId[2]=CESS-CAST-AA-20000412-8873-c13|ClusterType[2]=Gen|MentionSpan[2]=12-34|MentionMisc[2]=CorefType:ident
# 14	,	,	PUNCT	fc	PunctType=Comm	16	punct	16:punct	_
# 15	que	que	PRON	pr0cn000	PronType=Int,Rel	16	nsubj	16:nsubj	Entity=(CESSCASTAA200004128873c13--1-CorefType:ident,gstype:gen)
# 16	contenía	contener	VERB	vmii3s0	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	13	acl	13:acl	SpaceAfter=No
# 17	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 18	asi	asi	ADV	rg	_	16	advmod	16:advmod	MWE=asi_mismo|MWEPOS=ADV
# 19	mismo	mismo	ADJ	_	_	18	fixed	18:fixed	SpaceAfter=No
# 20	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 21	especificaciones	especificación	NOUN	ncfp000	Gender=Fem|Number=Plur	16	obj	16:obj	Entity=(CESSCASTAA200004128873s8.sn.35--1-gstype:gen
# 22	relativas	relativo	ADJ	aq0fp0	Gender=Fem|Number=Plur	21	amod	21:amod	_
# 23	a	a	ADP	sps00	_	25	case	25:case	_
# 24	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	25	det	25:det	Entity=(CESSCASTAA200004128873s8.sn.44--2-gstype:gen,HomoDD
# 25	calidad	calidad	NOUN	ncfs000	Gender=Fem|Number=Sing	22	nmod	22:nmod	_
# 26	de	de	ADP	sps00	_	28	case	28:case	_
# 27	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	28	det	28:det	Entity=(CESSCASTAA200004128873s8.sn.53--2-gstype:gen,HomoDD
# 28	gasolina	gasolina	NOUN	ncfs000	Gender=Fem|Number=Sing	25	nmod	25:nmod	Entity=CESSCASTAA200004128873s8.sn.53)
# 29	y	y	CCONJ	cc	_	32	cc	32:cc	_
# 30-31	del	_	_	_	_	_	_	_	_
# 30	de	de	ADP	spcms	_	32	case	32:case	_
# 31	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	32	det	32:det	_
# 32	gasóleo	gasóleo	NOUN	ncms000	Gender=Masc|Number=Sing	28	conj	28:conj	Entity=(CESSCASTAA200004128873s8.sn.63--1-gstype:gen,HomoDD
# 33	de	de	ADP	sps00	_	34	case	34:case	_
# 34	automoción	automoción	NOUN	ncfs000	Gender=Fem|Number=Sing	32	nmod	32:nmod	SpaceAfter=No|Entity=CESSCASTAA200004128873s8.sn.63)CESSCASTAA200004128873s8.sn.44)CESSCASTAA200004128873s8.sn.35)CESSCASTAA200004128873c13)CESSCASTAA200004128873s8.sn.15)
# 35	.	.	PUNCT	fp	PunctType=Peri	10	punct	10:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000412-8873-s9
# # text = El Gobierno español presentó a la Comisión una solicitud de excepción para seguir comercializando gasolina con plomo hasta el 1 de julio de 2003, supeditada a la condición de que la institución comunitaria autorizase a España a demandar una prórroga suplementaria hasta enero de 2005.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200004128873s9.sn.2-organization-2-gstype:spec
# 2	Gobierno	Gobierno	PROPN	np00000	_	4	nsubj	4:nsubj	_
# 3	español	español	ADJ	aq0ms0	Gender=Masc|Number=Sing	2	amod	2:amod	Entity=CESSCASTAA200004128873s9.sn.2)
# 4	presentó	presentar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 5	a	a	ADP	sps00	_	7	case	7:case	_
# 6	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	7	det	7:det	Entity=(CESSCASTAA200004128873c14-organization-2-CorefType:ident,gstype:spec
# 7	Comisión	Comisión	PROPN	np00000	_	4	obj	4:obj	Entity=CESSCASTAA200004128873c14)
# 8	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	9	det	9:det	Entity=(CESSCASTAA200004128873s9.sn.20--2-gstype:gen
# 9	solicitud	solicitud	NOUN	ncfs000	Gender=Fem|Number=Sing	4	obj	4:obj	_
# 10	de	de	ADP	sps00	_	11	case	11:case	_
# 11	excepción	excepción	NOUN	ncfs000	Gender=Fem|Number=Sing	9	nmod	9:nmod	_
# 12	para	para	ADP	sps00	_	13	mark	13:mark	_
# 13	seguir	seguir	VERB	vmn0000	VerbForm=Inf	11	acl	11:acl	_
# 14	comercializando	comercializar	VERB	vmg0000	VerbForm=Ger	13	xcomp	13:xcomp	_
# 15	gasolina	gasolina	NOUN	ncfs000	Gender=Fem|Number=Sing	14	obj	14:obj	Entity=(CESSCASTAA200004128873c2--1-CorefType:ident,gstype:gen
# 16	con	con	ADP	sps00	_	17	case	17:case	_
# 17	plomo	plomo	NOUN	ncms000	Gender=Masc|Number=Sing	15	nmod	15:nmod	Entity=(CESSCASTAA200004128873c9--1-CorefType:ident,gstype:gen)CESSCASTAA200004128873c2)
# 18	hasta	hasta	ADP	sps00	_	20	case	20:case	_
# 19	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	20	det	20:det	Entity=(CESSCASTAA200004128873s9.sn.51-time-2-gstype:spec
# 20	1	1	NUM	_	NumForm=Digit|NumType=Card	13	obl	13:obl	MWE=1_de_julio_de_2003|MWEPOS=NOUN
# 21	de	de	ADP	_	_	22	case	22:case	_
# 22	julio	julio	NOUN	_	_	20	compound	20:compound	_
# 23	de	de	ADP	_	_	24	case	24:case	_
# 24	2003	2003	NUM	_	NumForm=Digit|NumType=Card	20	compound	20:compound	SpaceAfter=No|Entity=CESSCASTAA200004128873s9.sn.51)
# 25	,	,	PUNCT	fc	PunctType=Comm	26	punct	26:punct	_
# 26	supeditada	supeditado	ADJ	aq0fsp	Gender=Fem|Number=Sing|VerbForm=Part	11	amod	11:amod	_
# 27	a	a	ADP	sps00	_	29	case	29:case	_
# 28	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	29	det	29:det	Entity=(CESSCASTAA200004128873s9.sn.63--2-gstype:gen,HomoDD
# 29	condición	condición	NOUN	ncfs000	Gender=Fem|Number=Sing	26	obj	26:obj	_
# 30	de	de	ADP	sps00	_	35	mark	35:mark	_
# 31	que	que	SCONJ	cs	_	35	mark	35:mark	_
# 32	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	33	det	33:det	Entity=(CESSCASTAA200004128873s9.sn.74--2-gstype:gen,HomoDD
# 33	institución	institución	NOUN	ncfs000	Gender=Fem|Number=Sing	35	nsubj	35:nsubj	_
# 34	comunitaria	comunitario	ADJ	aq0fs0	Gender=Fem|Number=Sing	33	amod	33:amod	Entity=CESSCASTAA200004128873s9.sn.74)
# 35	autorizase	autorizar	VERB	vmsi3s0	Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	29	acl	29:acl	_
# 36	a	a	ADP	sps00	_	37	case	37:case	_
# 37	España	España	PROPN	np00000	_	35	iobj	35:iobj	Entity=(CESSCASTAA200004128873c16-organization-1-gstype:spec)
# 38	a	a	ADP	sps00	_	39	mark	39:mark	_
# 39	demandar	demandar	VERB	vmn0000	VerbForm=Inf	35	xcomp	35:xcomp	_
# 40	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	41	det	41:det	Entity=(CESSCASTAA200004128873s9.sn.96--2-gstype:gen
# 41	prórroga	prórroga	NOUN	ncfs000	Gender=Fem|Number=Sing	39	obj	39:obj	_
# 42	suplementaria	suplementario	ADJ	aq0fs0	Gender=Fem|Number=Sing	41	amod	41:amod	Entity=CESSCASTAA200004128873s9.sn.96)
# 43	hasta	hasta	ADP	sps00	_	44	case	44:case	_
# 44	enero	enero	NOUN	_	_	39	obl	39:obl	MWE=enero_de_2005|MWEPOS=NOUN|Entity=(CESSCASTAA200004128873c15-time-1-CorefType:ident,gstype:spec
# 45	de	de	ADP	_	_	46	case	46:case	_
# 46	2005	2005	NUM	_	NumForm=Digit|NumType=Card	44	compound	44:compound	SpaceAfter=No|Entity=CESSCASTAA200004128873c15)CESSCASTAA200004128873s9.sn.63)CESSCASTAA200004128873s9.sn.20)
# 47	.	.	PUNCT	fp	PunctType=Peri	4	punct	4:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000412-8873-s10
# # text = La Comisión decidió el 20 de diciembre de 1999 autorizar a España la venta de este carburante hasta el 31 de diciembre de 2001.
# 1	La	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200004128873c14-organization-2-CorefType:ident,gstype:spec
# 2	Comisión	Comisión	PROPN	np00000	_	3	nsubj	3:nsubj	Entity=CESSCASTAA200004128873c14)
# 3	decidió	decidir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 4	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	5	det	5:det	Entity=(CESSCASTAA200004128873s10.sn.9-time-2-gstype:spec
# 5	20	20	NUM	_	NumForm=Digit|NumType=Card	3	obl	3:obl	MWE=20_de_diciembre_de_1999|MWEPOS=NOUN
# 6	de	de	ADP	_	_	7	case	7:case	_
# 7	diciembre	diciembre	NOUN	_	_	5	compound	5:compound	_
# 8	de	de	ADP	_	_	9	case	9:case	_
# 9	1999	1999	NUM	_	NumForm=Digit|NumType=Card	5	compound	5:compound	Entity=CESSCASTAA200004128873s10.sn.9)
# 10	autorizar	autorizar	VERB	vmn0000	VerbForm=Inf	3	xcomp	3:xcomp	_
# 11	a	a	ADP	sps00	_	12	case	12:case	_
# 12	España	España	PROPN	np00000	_	10	obj	10:obj	Entity=(CESSCASTAA200004128873c16-organization-1-CorefType:ident,gstype:spec)
# 13	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	14	det	14:det	Entity=(CESSCASTAA200004128873s10.sn.23--2-gstype:gen,HomoDD
# 14	venta	venta	NOUN	ncfs000	Gender=Fem|Number=Sing	10	obj	10:obj	_
# 15	de	de	ADP	sps00	_	17	case	17:case	_
# 16	este	este	DET	dd0ms0	Gender=Masc|Number=Sing|PronType=Dem	17	det	17:det	Entity=(CESSCASTAA200004128873c2--2-CorefType:ident,gstype:gen
# 17	carburante	carburante	NOUN	ncms000	Gender=Masc|Number=Sing	14	nmod	14:nmod	Entity=CESSCASTAA200004128873c2)CESSCASTAA200004128873s10.sn.23)
# 18	hasta	hasta	ADP	sps00	_	20	case	20:case	_
# 19	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	20	det	20:det	Entity=(CESSCASTAA200004128873s10.sn.39-time-2-gstype:spec
# 20	31	31	NUM	_	NumForm=Digit|NumType=Card	10	obl	10:obl	MWE=31_de_diciembre_de_2001|MWEPOS=NOUN
# 21	de	de	ADP	_	_	22	case	22:case	_
# 22	diciembre	diciembre	NOUN	_	_	20	compound	20:compound	_
# 23	de	de	ADP	_	_	24	case	24:case	_
# 24	2001	2001	NUM	_	NumForm=Digit|NumType=Card	20	compound	20:compound	SpaceAfter=No|Entity=CESSCASTAA200004128873s10.sn.39)
# 25	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000412-8873-s11
# # text = El Real Decreto publicado hoy completa la transposición de la directiva comunitaria en la parte relativa a la prohibición de la distribución de gasolinas con plomo en el territorio nacional.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200004128873c1-other-2-CorefType:ident,gstype:spec
# 2	Real	Real	PROPN	np00000	_	6	nsubj	6:nsubj	MWE=Real_Decreto|MWEPOS=PROPN
# 3	Decreto	Decreto	PROPN	_	_	2	flat	2:flat	_
# 4	publicado	publicado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	2	amod	2:amod	_
# 5	hoy	hoy	ADV	rg	_	4	advmod	4:advmod	Entity=CESSCASTAA200004128873c1)
# 6	completa	completar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 7	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	8:det	Entity=(CESSCASTAA200004128873s11.sn.15--2-gstype:gen,HomoDD
# 8	transposición	transposición	NOUN	ncfs000	Gender=Fem|Number=Sing	6	obj	6:obj	_
# 9	de	de	ADP	sps00	_	11	case	11:case	_
# 10	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	11	det	11:det	Entity=(CESSCASTAA200004128873c13--2-CorefType:ident,gstype:gen
# 11	directiva	directiva	NOUN	ncfs000	Gender=Fem|Number=Sing	8	nmod	8:nmod	_
# 12	comunitaria	comunitario	ADJ	aq0fs0	Gender=Fem|Number=Sing	11	amod	11:amod	Entity=CESSCASTAA200004128873c13)CESSCASTAA200004128873s11.sn.15)
# 13	en	en	ADP	sps00	_	15	case	15:case	_
# 14	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	15	det	15:det	Entity=(CESSCASTAA200004128873s11.sn.34--2-gstype:gen,HomoDD
# 15	parte	parte	NOUN	ncfs000	Gender=Fem|Number=Sing	6	obl	6:obl	_
# 16	relativa	relativo	ADJ	aq0fs0	Gender=Fem|Number=Sing	15	amod	15:amod	_
# 17	a	a	ADP	sps00	_	19	case	19:case	_
# 18	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	19	det	19:det	Entity=(CESSCASTAA200004128873c17--2-CorefType:ident,gstype:gen,HomoDD
# 19	prohibición	prohibición	NOUN	ncfs000	Gender=Fem|Number=Sing	16	nmod	16:nmod	_
# 20	de	de	ADP	sps00	_	22	case	22:case	_
# 21	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	22	det	22:det	Entity=(CESSCASTAA200004128873s11.sn.53--2-gstype:gen,HomoDD
# 22	distribución	distribución	NOUN	ncfs000	Gender=Fem|Number=Sing	19	nmod	19:nmod	_
# 23	de	de	ADP	sps00	_	24	case	24:case	_
# 24	gasolinas	gasolina	NOUN	ncfp000	Gender=Fem|Number=Plur	22	nmod	22:nmod	Entity=(CESSCASTAA200004128873c2--1-CorefType:ident,gstype:gen
# 25	con	con	ADP	sps00	_	26	case	26:case	_
# 26	plomo	plomo	NOUN	ncms000	Gender=Masc|Number=Sing	24	nmod	24:nmod	Entity=(CESSCASTAA200004128873c9--1-CorefType:ident,gstype:gen)CESSCASTAA200004128873c2)CESSCASTAA200004128873s11.sn.53)
# 27	en	en	ADP	sps00	_	29	case	29:case	_
# 28	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	29	det	29:det	Entity=(CESSCASTAA200004128873s11.sn.73--2-gstype:gen,HomoDD
# 29	territorio	territorio	NOUN	ncms000	Gender=Masc|Number=Sing	19	nmod	19:nmod	_
# 30	nacional	nacional	ADJ	aq0cs0	Number=Sing	29	amod	29:amod	SpaceAfter=No|Entity=CESSCASTAA200004128873s11.sn.73)CESSCASTAA200004128873c17)CESSCASTAA200004128873s11.sn.34)
# 31	.	.	PUNCT	fp	PunctType=Peri	6	punct	6:punct	_
#
#
# # global.Entity = eid-etype-head-other
# # newdoc id = CESS-CAST-AA-20000504-2181
# # sent_id = CESS-CAST-AA-20000504-2181-s1
# # text = El campeón Blooming, de Santa Cruz, logró mantenerse hoy en la punta de la tabla de posiciones del torneo boliviano de fútbol al conseguir un empate 2-2 en su visita al Atlético Pompeya, en la ciudad amazónica de Trinidad, al noreste de Bolivia.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200005042181c3-organization-2-gstype:spec
# 2	campeón	campeón	NOUN	ncms000	Gender=Masc|Number=Sing	9	nsubj	9:nsubj	_
# 3	Blooming	Blooming	PROPN	np00000	_	2	appos	2:appos	SpaceAfter=No|Entity=(CESSCASTAA200005042181s1.sn.7-organization-1-gstype:spec)
# 4	,	,	PUNCT	fc	PunctType=Comm	6	punct	6:punct	_
# 5	de	de	ADP	sps00	_	6	case	6:case	_
# 6	Santa	Santa	PROPN	np00000	_	2	nmod	2:nmod	MWE=Santa_Cruz|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181c7-place-1-gstype:spec
# 7	Cruz	Cruz	PROPN	_	_	6	flat	6:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181c7)
# 8	,	,	PUNCT	fc	PunctType=Comm	6	punct	6:punct	Entity=CESSCASTAA200005042181c3)
# 9	logró	lograr	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 10-11	mantenerse	_	_	_	_	_	_	_	_
# 10	mantener	mantener	VERB	vmn0000	VerbForm=Inf	9	xcomp	9:xcomp	_
# 11	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	10	obj	10:obj	_
# 12	hoy	hoy	ADV	rg	_	10	advmod	10:advmod	_
# 13	en	en	ADP	sps00	_	15	case	15:case	_
# 14	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	15	det	15:det	Entity=(CESSCASTAA200005042181s1.sn.29--2-gstype:gen,HomoDD
# 15	punta	punta	NOUN	ncfs000	Gender=Fem|Number=Sing	10	obl	10:obl	_
# 16	de	de	ADP	sps00	_	18	case	18:case	_
# 17	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	18	det	18:det	Entity=(CESSCASTAA200005042181c6--2-gstype:gen,HomoDD
# 18	tabla	tabla	NOUN	ncfs000	Gender=Fem|Number=Sing	15	nmod	15:nmod	_
# 19	de	de	ADP	sps00	_	20	case	20:case	_
# 20	posiciones	posición	NOUN	ncfp000	Gender=Fem|Number=Plur	18	nmod	18:nmod	_
# 21-22	del	_	_	_	_	_	_	_	_
# 21	de	de	ADP	spcms	_	23	case	23:case	_
# 22	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	23	det	23:det	_
# 23	torneo	torneo	NOUN	ncms000	Gender=Masc|Number=Sing	18	nmod	18:nmod	Entity=(CESSCASTAA200005042181c4-other-1-gstype:spec
# 24	boliviano	boliviano	ADJ	aq0ms0	Gender=Masc|Number=Sing	23	amod	23:amod	_
# 25	de	de	ADP	sps00	_	26	case	26:case	_
# 26	fútbol	fútbol	NOUN	ncms000	Gender=Masc|Number=Sing	23	nmod	23:nmod	Entity=CESSCASTAA200005042181c4)CESSCASTAA200005042181c6)CESSCASTAA200005042181s1.sn.29)
# 27-28	al	_	_	_	_	_	_	_	_
# 27	a	a	ADP	spcms	_	29	case	29:case	_
# 28	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	29	det	29:det	_
# 29	conseguir	conseguir	VERB	vmn0000	VerbForm=Inf	9	advcl	9:advcl	_
# 30	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	Entity=(CESSCASTAA200005042181c2--2-gstype:gen
# 31	empate	empate	NOUN	ncms000	Gender=Masc|Number=Sing	29	obj	29:obj	_
# 32	2-2	2-2	NUM	_	NumForm=Digit|NumType=Card	31	appos	31:appos	Entity=(CESSCASTAA200005042181csingleton3-number-1-gstype:spec)CESSCASTAA200005042181c2)
# 33	en	en	ADP	sps00	_	35	case	35:case	_
# 34	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	35	det	35:det	Entity=(CESSCASTAA200005042181s1.sn.80--2-gstype:gen(CESSCASTAA200005042181c3-organization-1-CorefType:ident,gstype:spec)
# 35	visita	visita	NOUN	ncfs000	Gender=Fem|Number=Sing	29	obl	29:obl	_
# 36-37	al	_	_	_	_	_	_	_	_
# 36	a	a	ADP	spcms	_	38	case	38:case	Entity=(CESSCASTAA200005042181csingleton1--3
# 37	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	38:det	_
# 38	Atlético	Atlético	PROPN	np00000	_	35	nmod	35:nmod	MWE=Atlético_Pompeya|MWEPOS=PROPN|ClusterId[1]=CESS-CAST-AA-20000504-2181-csingleton1|ClusterType[1]=_|MentionSpan[1]=36-39|ClusterId[2]=CESS-CAST-AA-20000504-2181-s1.sn.88|ClusterType[2]=Spec.organization|MentionSpan[2]=38-39|Entity=(CESSCASTAA200005042181s1.sn.88-organization-1-gstype:spec
# 39	Pompeya	Pompeya	PROPN	_	_	38	flat	38:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s1.sn.88)CESSCASTAA200005042181csingleton1)CESSCASTAA200005042181s1.sn.80)
# 40	,	,	PUNCT	fc	PunctType=Comm	43	punct	43:punct	Entity=(CESSCASTAA200005042181csingleton2--4
# 41	en	en	ADP	sps00	_	43	case	43:case	_
# 42	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	43	det	43:det	Entity=(CESSCASTAA200005042181s1.sn.95-place-2-gstype:spec
# 43	ciudad	ciudad	NOUN	ncfs000	Gender=Fem|Number=Sing	29	obl	29:obl	ClusterId[1]=CESS-CAST-AA-20000504-2181-csingleton2|ClusterType[1]=_|MentionSpan[1]=40-52|ClusterId[2]=CESS-CAST-AA-20000504-2181-s1.sn.95|ClusterType[2]=Spec.location|MentionSpan[2]=42-52
# 44	amazónica	amazónico	ADJ	aq0fs0	Gender=Fem|Number=Sing	43	amod	43:amod	_
# 45	de	de	ADP	sps00	_	46	case	46:case	_
# 46	Trinidad	Trinidad	PROPN	np00000	_	43	nmod	43:nmod	SpaceAfter=No|Entity=(CESSCASTAA200005042181s1.sn.106-place-1-gstype:spec)
# 47	,	,	PUNCT	fc	PunctType=Comm	50	punct	50:punct	_
# 48-49	al	_	_	_	_	_	_	_	_
# 48	a	a	ADP	spcms	_	50	case	50:case	_
# 49	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	50	det	50:det	_
# 50	noreste	noreste	NOUN	ncms000	Gender=Masc|Number=Sing	43	nmod	43:nmod	Entity=(CESSCASTAA200005042181s1.sn.113-place-1-gstype:spec
# 51	de	de	ADP	sps00	_	52	case	52:case	_
# 52	Bolivia	Bolivia	PROPN	np00000	_	50	nmod	50:nmod	SpaceAfter=No|Entity=(CESSCASTAA200005042181s1.sn.119-place-1-gstype:spec)CESSCASTAA200005042181s1.sn.113)CESSCASTAA200005042181s1.sn.95)CESSCASTAA200005042181csingleton2)
# 53	.	.	PUNCT	fp	PunctType=Peri	9	punct	9:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000504-2181-s2
# # text = El artillero Víctor Hugo "Tucho" Antelo marcó los dos goles que dieron el empate a Blooming, dirigido por el técnico argentino Carlos Ramacciotti, y le permitieron sumar 21 puntos en la duodécima fecha del certamen nacional.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200005042181s2.sn.2-person-2-gstype:spec
# 2	artillero	artillero	NOUN	ncms000	Gender=Masc|Number=Sing	7	nsubj	7:nsubj	_
# 3	Víctor	Víctor	PROPN	np00000	_	2	appos	2:appos	MWE=Víctor_Hugo_"Tucho"_Antelo|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s2.sn.7-person-1-gstype:spec
# 4	Hugo	Hugo	PROPN	_	_	3	flat	3:flat	_
# 5	"Tucho"	"Tucho"	PROPN	_	_	3	flat	3:flat	_
# 6	Antelo	Antelo	PROPN	_	_	3	flat	3:flat	Entity=CESSCASTAA200005042181s2.sn.7)CESSCASTAA200005042181s2.sn.2)
# 7	marcó	marcar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 8	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	10	det	10:det	Entity=(CESSCASTAA200005042181c1--3-gstype:gen,HomoDD
# 9	dos	dos	NUM	dn0cp0	Number=Plur|NumType=Card	8	nummod	8:nummod	_
# 10	goles	gol	NOUN	ncmp000	Gender=Masc|Number=Plur	7	obj	7:obj	_
# 11	que	que	PRON	pr0cn000	PronType=Int,Rel	12	nsubj	12:nsubj	Entity=(CESSCASTAA200005042181c1--1-CorefType:ident,gstype:gen)
# 12	dieron	dar	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	10	acl	10:acl	_
# 13	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	14	det	14:det	Entity=(CESSCASTAA200005042181c2--2-CorefType:ident,gstype:gen
# 14	empate	empate	NOUN	ncms000	Gender=Masc|Number=Sing	12	obj	12:obj	Entity=CESSCASTAA200005042181c2)
# 15	a	a	ADP	sps00	_	16	case	16:case	_
# 16	Blooming	Blooming	PROPN	np00000	_	12	obj	12:obj	SpaceAfter=No|Entity=(CESSCASTAA200005042181c3-organization-1-CorefType:ident,gstype:spec
# 17	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 18	dirigido	dirigido	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	16	amod	16:amod	_
# 19	por	por	ADP	sps00	_	21	case	21:case	_
# 20	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	21	det	21:det	Entity=(CESSCASTAA200005042181s2.sn.42-person-2-gstype:spec
# 21	técnico	técnico	NOUN	ncms000	Gender=Masc|Number=Sing	18	obj	18:obj	_
# 22	argentino	argentino	ADJ	aq0ms0	Gender=Masc|Number=Sing	21	amod	21:amod	_
# 23	Carlos	Carlos	PROPN	np00000	_	21	appos	21:appos	MWE=Carlos_Ramacciotti|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s2.sn.50-person-1-gstype:spec
# 24	Ramacciotti	Ramacciotti	PROPN	_	_	23	flat	23:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s2.sn.50)CESSCASTAA200005042181s2.sn.42)
# 25	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	Entity=CESSCASTAA200005042181c3)
# 26	y	y	CCONJ	cc	_	28	cc	28:cc	_
# 27	le	él	PRON	pp3csd00	Case=Dat|Number=Sing|Person=3|PronType=Prs	28	iobj	28:iobj	Entity=(CESSCASTAA200005042181c3-organization-1-CorefType:ident,gstype:spec)
# 28	permitieron	permitir	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	12	conj	12:conj	_
# 29	sumar	sumar	VERB	vmn0000	VerbForm=Inf	28	xcomp	28:xcomp	_
# 30	21	21	NUM	_	NumForm=Digit|NumType=Card	31	nummod	31:nummod	Entity=(CESSCASTAA200005042181s2.sn.65--2-gstype:gen
# 31	puntos	punto	NOUN	ncmp000	Gender=Masc|Number=Plur	29	obj	29:obj	Entity=CESSCASTAA200005042181s2.sn.65)
# 32	en	en	ADP	sps00	_	35	case	35:case	_
# 33	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	35	det	35:det	Entity=(CESSCASTAA200005042181s2.sn.73--3-gstype:gen,HomoDD
# 34	duodécima	duodécimo	ADJ	ao0fs0	Gender=Fem|Number=Sing|NumType=Ord	35	amod	35:amod	_
# 35	fecha	fecha	NOUN	ncfs000	Gender=Fem|Number=Sing	29	obl	29:obl	_
# 36-37	del	_	_	_	_	_	_	_	_
# 36	de	de	ADP	spcms	_	38	case	38:case	_
# 37	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	38:det	_
# 38	certamen	certamen	NOUN	ncms000	Gender=Masc|Number=Sing	35	nmod	35:nmod	Entity=(CESSCASTAA200005042181c4-other-1-CorefType:ident,gstype:spec
# 39	nacional	nacional	ADJ	aq0cs0	Number=Sing	38	amod	38:amod	SpaceAfter=No|Entity=CESSCASTAA200005042181c4)CESSCASTAA200005042181s2.sn.73)CESSCASTAA200005042181c1)
# 40	.	.	PUNCT	fp	PunctType=Peri	7	punct	7:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000504-2181-s3
# # text = En la población rural de Montero, en el departamento de Santa Cruz, el Guabirá, dirigido por el entrenador español Manuel Núñez, se impuso al Independiente Petrolero, de Sucre, por 2-1, con dos goles anotados por el argentino Marcelo Zeballos.
# 1	En	en	ADP	sps00	_	3	case	3:case	_
# 2	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	3	det	3:det	Entity=(CESSCASTAA200005042181s3.sn.5-place-2-gstype:spec
# 3	población	población	NOUN	ncfs000	Gender=Fem|Number=Sing	27	obl	27:obl	_
# 4	rural	rural	ADJ	aq0cs0	Number=Sing	3	amod	3:amod	_
# 5	de	de	ADP	sps00	_	6	case	6:case	_
# 6	Montero	Montero	PROPN	np00000	_	3	nmod	3:nmod	SpaceAfter=No|Entity=(CESSCASTAA200005042181s3.sn.16-place-1-gstype:spec)
# 7	,	,	PUNCT	fc	PunctType=Comm	10	punct	10:punct	_
# 8	en	en	ADP	sps00	_	10	case	10:case	_
# 9	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	10	det	10:det	Entity=(CESSCASTAA200005042181s3.sn.23-place-2-gstype:spec
# 10	departamento	departamento	NOUN	ncms000	Gender=Masc|Number=Sing	3	nmod	3:nmod	_
# 11	de	de	ADP	sps00	_	12	case	12:case	_
# 12	Santa	Santa	PROPN	np00000	_	10	nmod	10:nmod	MWE=Santa_Cruz|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s3.sn.31-place-1-gstype:spec
# 13	Cruz	Cruz	PROPN	_	_	12	flat	12:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s3.sn.31)CESSCASTAA200005042181s3.sn.23)
# 14	,	,	PUNCT	fc	PunctType=Comm	10	punct	10:punct	Entity=CESSCASTAA200005042181s3.sn.5)
# 15	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	16	det	16:det	Entity=(CESSCASTAA200005042181c5-place-2-gstype:spec
# 16	Guabirá	Guabirá	PROPN	np00000	_	27	nsubj	27:nsubj	SpaceAfter=No
# 17	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 18	dirigido	dirigido	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	16	amod	16:amod	_
# 19	por	por	ADP	sps00	_	21	case	21:case	_
# 20	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	21	det	21:det	Entity=(CESSCASTAA200005042181s3.sn.47-person-2-gstype:spec
# 21	entrenador	entrenador	NOUN	ncms000	Gender=Masc|Number=Sing	18	obj	18:obj	_
# 22	español	español	ADJ	aq0ms0	Gender=Masc|Number=Sing	21	amod	21:amod	_
# 23	Manuel	Manuel	PROPN	np00000	_	21	appos	21:appos	MWE=Manuel_Núñez|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s3.sn.55-person-1-gstype:spec
# 24	Núñez	Núñez	PROPN	_	_	23	flat	23:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s3.sn.55)CESSCASTAA200005042181s3.sn.47)
# 25	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	Entity=CESSCASTAA200005042181c5)
# 26	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	27	expl:pv	27:expl:pv	_
# 27	impuso	imponer	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 28-29	al	_	_	_	_	_	_	_	_
# 28	a	a	ADP	spcms	_	30	case	30:case	_
# 29	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	30	det	30:det	_
# 30	Independiente	Independiente	PROPN	np00000	_	27	obj	27:obj	MWE=Independiente_Petrolero|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s3.sn.66-organization-1-gstype:spec
# 31	Petrolero	Petrolero	PROPN	_	_	30	flat	30:flat	SpaceAfter=No
# 32	,	,	PUNCT	fc	PunctType=Comm	34	punct	34:punct	_
# 33	de	de	ADP	sps00	_	34	case	34:case	_
# 34	Sucre	Sucre	PROPN	np00000	_	30	nmod	30:nmod	SpaceAfter=No|Entity=(CESSCASTAA200005042181s3.sn.73-place-1-gstype:spec)
# 35	,	,	PUNCT	fc	PunctType=Comm	34	punct	34:punct	Entity=CESSCASTAA200005042181s3.sn.66)
# 36	por	por	ADP	sps00	_	37	case	37:case	_
# 37	2-1	2-1	NUM	_	NumForm=Digit|NumType=Card	27	obl	27:obl	SpaceAfter=No|Entity=(CESSCASTAA200005042181s3.sn.80-number-1-gstype:spec
# 38	,	,	PUNCT	fc	PunctType=Comm	41	punct	41:punct	_
# 39	con	con	ADP	sps00	_	41	case	41:case	_
# 40	dos	dos	NUM	dn0cp0	Number=Plur|NumType=Card	41	nummod	41:nummod	Entity=(CESSCASTAA200005042181s3.sn.87--2-gstype:gen
# 41	goles	gol	NOUN	ncmp000	Gender=Masc|Number=Plur	37	nmod	37:nmod	_
# 42	anotados	anotado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	41	amod	41:amod	_
# 43	por	por	ADP	sps00	_	45	case	45:case	_
# 44	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	45	det	45:det	Entity=(CESSCASTAA200005042181s3.sn.98-person-2-gstype:spec
# 45	argentino	argentino	NOUN	ncms000	Gender=Masc|Number=Sing	42	obj	42:obj	_
# 46	Marcelo	Marcelo	PROPN	np00000	_	45	appos	45:appos	MWE=Marcelo_Zeballos|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s3.sn.103-person-1-gstype:spec
# 47	Zeballos	Zeballos	PROPN	_	_	46	flat	46:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s3.sn.103)CESSCASTAA200005042181s3.sn.98)CESSCASTAA200005042181s3.sn.87)CESSCASTAA200005042181s3.sn.80)
# 48	.	.	PUNCT	fp	PunctType=Peri	27	punct	27:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000504-2181-s4
# # text = La victoria permite al Guabirá alcanzar los 20 puntos y lograr el segundo lugar de las posiciones.
# 1	La	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200005042181s4.sn.2--2-gstype:gen
# 2	victoria	victoria	NOUN	ncfs000	Gender=Fem|Number=Sing	3	nsubj	3:nsubj	Entity=CESSCASTAA200005042181s4.sn.2)
# 3	permite	permitir	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 4-5	al	_	_	_	_	_	_	_	_
# 4	a	a	ADP	spcms	_	6	case	6:case	_
# 5	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	_
# 6	Guabirá	Guabirá	PROPN	np00000	_	3	iobj	3:iobj	Entity=(CESSCASTAA200005042181c5-place-1-CorefType:ident,gstype:spec)
# 7	alcanzar	alcanzar	VERB	vmn0000	VerbForm=Inf	3	xcomp	3:xcomp	_
# 8	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	9	det	9:det	Entity=(CESSCASTAA200005042181s4.sn.19--3-gstype:gen
# 9	20	20	NUM	_	NumForm=Digit|NumType=Card	10	nummod	10:nummod	_
# 10	puntos	punto	NOUN	ncmp000	Gender=Masc|Number=Plur	7	obj	7:obj	Entity=CESSCASTAA200005042181s4.sn.19)
# 11	y	y	CCONJ	cc	_	12	cc	12:cc	_
# 12	lograr	lograr	VERB	vmn0000	VerbForm=Inf	7	conj	7:conj	_
# 13	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	det	15:det	Entity=(CESSCASTAA200005042181s4.sn.30--3-gstype:gen,HomoDD
# 14	segundo	segundo	ADJ	ao0ms0	Gender=Masc|Number=Sing|NumType=Ord	15	amod	15:amod	_
# 15	lugar	lugar	NOUN	ncms000	Gender=Masc|Number=Sing	12	obj	12:obj	_
# 16	de	de	ADP	sps00	_	18	case	18:case	_
# 17	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	18	det	18:det	Entity=(CESSCASTAA200005042181c6--2-CorefType:ident,gstype:gen
# 18	posiciones	posición	NOUN	ncfp000	Gender=Fem|Number=Plur	15	nmod	15:nmod	SpaceAfter=No|Entity=CESSCASTAA200005042181c6)CESSCASTAA200005042181s4.sn.30)
# 19	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000504-2181-s5
# # text = El Oriente Petrolero, en la ciudad de Santa Cruz, venció 2-0 al Wilstermann de Cochabamba, dirigido por el entrenador argentino Carlos Habegger, con dianas conseguidas por el delantero boliviano Milton Coimbra y el zaguero argentino Miguel Angel Abrigo.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200005042181s5.sn.2-organization-2-gstype:spec
# 2	Oriente	Oriente	PROPN	np00000	_	12	nsubj	12:nsubj	MWE=Oriente_Petrolero|MWEPOS=PROPN
# 3	Petrolero	Petrolero	PROPN	_	_	2	flat	2:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s5.sn.2)
# 4	,	,	PUNCT	fc	PunctType=Comm	7	punct	7:punct	_
# 5	en	en	ADP	sps00	_	7	case	7:case	_
# 6	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	7	det	7:det	Entity=(CESSCASTAA200005042181c7-place-2-CorefType:ident,gstype:spec
# 7	ciudad	ciudad	NOUN	ncfs000	Gender=Fem|Number=Sing	12	obl	12:obl	_
# 8	de	de	ADP	sps00	_	9	case	9:case	_
# 9	Santa	Santa	PROPN	np00000	_	7	nmod	7:nmod	MWE=Santa_Cruz|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s5.sn.19-place-1-gstype:spec
# 10	Cruz	Cruz	PROPN	_	_	9	flat	9:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s5.sn.19)CESSCASTAA200005042181c7)
# 11	,	,	PUNCT	fc	PunctType=Comm	7	punct	7:punct	_
# 12	venció	vencer	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 13	2-0	2-0	NUM	_	NumForm=Digit|NumType=Card	12	obl	12:obl	Entity=(CESSCASTAA200005042181s5.sn.25-number-1-gstype:spec)
# 14-15	al	_	_	_	_	_	_	_	_
# 14	a	a	ADP	spcms	_	16	case	16:case	_
# 15	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	16	det	16:det	_
# 16	Wilstermann	Wilstermann	PROPN	np00000	_	12	obj	12:obj	MWE=Wilstermann_de_Cochabamba|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s5.sn.31-organization-1-gstype:spec
# 17	de	de	ADP	_	_	18	case	18:case	_
# 18	Cochabamba	Cochabamba	PROPN	_	_	16	flat	16:flat	SpaceAfter=No
# 19	,	,	PUNCT	fc	PunctType=Comm	20	punct	20:punct	_
# 20	dirigido	dirigido	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	16	amod	16:amod	_
# 21	por	por	ADP	sps00	_	23	case	23:case	_
# 22	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	23	det	23:det	Entity=(CESSCASTAA200005042181s5.sn.41-person-2-gstype:spec
# 23	entrenador	entrenador	NOUN	ncms000	Gender=Masc|Number=Sing	20	obj	20:obj	_
# 24	argentino	argentino	ADJ	aq0ms0	Gender=Masc|Number=Sing	23	amod	23:amod	_
# 25	Carlos	Carlos	PROPN	np00000	_	23	appos	23:appos	MWE=Carlos_Habegger|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s5.sn.49-person-1-gstype:spec
# 26	Habegger	Habegger	PROPN	_	_	25	flat	25:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s5.sn.49)CESSCASTAA200005042181s5.sn.41)
# 27	,	,	PUNCT	fc	PunctType=Comm	20	punct	20:punct	Entity=CESSCASTAA200005042181s5.sn.31)
# 28	con	con	ADP	sps00	_	29	case	29:case	_
# 29	dianas	diana	NOUN	ncfp000	Gender=Fem|Number=Plur	12	obl	12:obl	Entity=(CESSCASTAA200005042181s5.sn.56--1-gstype:gen
# 30	conseguidas	conseguido	ADJ	aq0fpp	Gender=Fem|Number=Plur|VerbForm=Part	29	amod	29:amod	_
# 31	por	por	ADP	sps00	_	33	case	33:case	_
# 32	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	33	det	33:det	Entity=(CESSCASTAA200005042181s5.sn.66-person-2-gstype:spec
# 33	delantero	delantero	NOUN	ncms000	Gender=Masc|Number=Sing	30	obj	30:obj	_
# 34	boliviano	boliviano	ADJ	aq0ms0	Gender=Masc|Number=Sing	33	amod	33:amod	_
# 35	Milton	Milton	PROPN	np00000	_	33	appos	33:appos	MWE=Milton_Coimbra|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s5.sn.74-person-1-gstype:spec
# 36	Coimbra	Coimbra	PROPN	_	_	35	flat	35:flat	Entity=CESSCASTAA200005042181s5.sn.74)CESSCASTAA200005042181s5.sn.66)
# 37	y	y	CCONJ	cc	_	39	cc	39:cc	_
# 38	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	39	det	39:det	Entity=(CESSCASTAA200005042181s5.sn.79-person-2-gstype:spec
# 39	zaguero	zaguero	NOUN	ncms000	Gender=Masc|Number=Sing	33	conj	33:conj	_
# 40	argentino	argentino	ADJ	aq0ms0	Gender=Masc|Number=Sing	39	amod	39:amod	_
# 41	Miguel	Miguel	PROPN	np00000	_	39	appos	39:appos	MWE=Miguel_Angel_Abrigo|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s5.sn.87-person-1-gstype:spec
# 42	Angel	Angel	PROPN	_	_	41	flat	41:flat	_
# 43	Abrigo	Abrigo	PROPN	_	_	41	flat	41:flat	SpaceAfter=No|Entity=CESSCASTAA200005042181s5.sn.87)CESSCASTAA200005042181s5.sn.79)CESSCASTAA200005042181s5.sn.56)
# 44	.	.	PUNCT	fp	PunctType=Peri	12	punct	12:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000504-2181-s6
# # text = En el estadio Hernando Siles de La Paz, el The Strongest, del entrenador colombiano Oscar Aristizábal, perdió la oportunidad de acercarse al campeón y empató a dos goles con el modesto Mariscal Braun, equipo de propiedad de la Cervecería Boliviana Nacional.
# 1	En	en	ADP	sps00	_	3	case	3:case	_
# 2	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	3	det	3:det	Entity=(CESSCASTAA200005042181s6.sn.5-place-2-gstype:spec
# 3	estadio	estadio	NOUN	ncms000	Gender=Masc|Number=Sing	21	obl	21:obl	_
# 4	Hernando	Hernando	PROPN	np00000	_	3	appos	3:appos	MWE=Hernando_Siles|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s6.sn.10-place-1-gstype:spec
# 5	Siles	Siles	PROPN	_	_	4	flat	4:flat	Entity=CESSCASTAA200005042181s6.sn.10)
# 6	de	de	ADP	sps00	_	8	case	8:case	_
# 7	La	el	DET	np00000	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	8:det	MWE=La_Paz|MWEPOS=PROPN|Entity=(CESSCASTAA200005042181s6.sn.16-place-2-gstype:spec
# 8	Paz	Paz	PROPN	_	_	3	nmod	3:nmod	SpaceAfter=No|Entity=CESSCASTAA200005042181s6.sn.16)CESSCASTAA200005042181s6.sn.5)
# 9	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	_
# 10	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	11	det	11:det	Entity=(CESSCASTAA200005042181c8-organization-2-gstype:spec
# 11	The	The	PROPN	np00000	_	21	nsubj	21:nsubj	MWE=The_Strongest|MWEPOS=PROPN
# 12	Strongest	Strongest	PROPN	_	_	11	flat	11:flat	SpaceAfter=No
# 13	,	,	PUNCT	fc	PunctType=Comm	16	punct	16:punct	_
# 14-15	del	_	_	_	_	_	_	_	_
# 14	de	de	ADP	spcms	_	16	case	16:case	_
# 15	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	16	det	16:det	_
# ...
# 33	someterán	someter	VERB	vmif3p0	Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin	28	acl	28:acl	_
# 34	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	35	det	35:det	Entity=(CESSCASTAA200008063784c14--2-CorefType:ident,gstype:gen(CESSCASTAA200008063784c1-person-1-CorefType:ident,gstype:spec)
# 35	detractores	detractor	NOUN	ncmp000	Gender=Masc|Number=Plur	33	nsubj	33:nsubj	SpaceAfter=No|Entity=CESSCASTAA200008063784c14)CESSCASTAA200008063784c20)CESSCASTAA200008063784s13.sn.52)
# 36	.	.	PUNCT	fp	PunctType=Peri	6	punct	6:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000806-3784-s14
# # text = Como líder del Partido del Despertar Nacional (PKB), Wahid fue elegido presidente pasando por encima de Megawati Sukarnoputri, cuya formación, el Partido Demócrata de Indonesia para la Lucha (PDIL), obtuvo la victoria en los comicios legislativos.
# 1	Como	como	SCONJ	cs	_	2	mark	2:mark	Entity=(CESSCASTAA200008063784c1-person-14-CorefType:ident,gstype:spec
# 2	líder	líder	NOUN	nccs000	Number=Sing	14	nmod	14:nmod	Entity=(CESSCASTAA200008063784c1-person-1-CorefType:pred.definit,gstype:spec
# 3-4	del	_	_	_	_	_	_	_	_
# 3	de	de	ADP	spcms	_	5	case	5:case	_
# 4	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	5	det	5:det	_
# 5	Partido	Partido	PROPN	np00000	_	2	nmod	2:nmod	MWE=Partido_del_Despertar_Nacional|MWEPOS=PROPN|Entity=(CESSCASTAA200008063784c21-organization-1-gstype:spec
# 6-7	del	_	_	_	_	_	_	_	_
# 6	de	de	ADP	_	_	8	case	8:case	_
# 7	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	8	det	8:det	_
# 8	Despertar	Despertar	PROPN	_	_	5	flat	5:flat	_
# 9	Nacional	Nacional	PROPN	_	_	8	flat	8:flat	_
# 10	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	11	punct	11:punct	SpaceAfter=No|Entity=(CESSCASTAA200008063784c21-organization-2-CorefType:pred.definit,gstype:spec
# 11	PKB	PKB	PROPN	np00000	_	5	flat	5:flat	SpaceAfter=No
# 12	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	11	punct	11:punct	SpaceAfter=No|Entity=CESSCASTAA200008063784c21)CESSCASTAA200008063784c21)CESSCASTAA200008063784c1)
# 13	,	,	PUNCT	fc	PunctType=Comm	2	punct	2:punct	_
# 14	Wahid	Wahid	PROPN	np00000	_	16	nsubj	16:nsubj	Entity=CESSCASTAA200008063784c1)
# 15	fue	ser	AUX	vsis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	16	aux	16:aux	_
# 16	elegido	elegir	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	0	root	0:root	_
# 17	presidente	presidente	NOUN	ncms000	Gender=Masc|Number=Sing	16	obj	16:obj	_
# 18	pasando	pasar	VERB	vmg0000	VerbForm=Ger	16	advcl	16:advcl	_
# 19	por	por	ADP	sps00	_	22	case	22:case	MWE=por_encima_de|MWEPOS=ADP
# 20	encima	encima	ADV	_	_	19	fixed	19:fixed	_
# 21	de	de	ADP	_	_	19	fixed	19:fixed	_
# 22	Megawati	Megawati	PROPN	np00000	_	18	obl	18:obl	MWE=Megawati_Sukarnoputri|MWEPOS=PROPN|Entity=(CESSCASTAA200008063784c24-person-1-gstype:spec
# 23	Sukarnoputri	Sukarnoputri	PROPN	_	_	22	flat	22:flat	SpaceAfter=No
# 24	,	,	PUNCT	fc	PunctType=Comm	40	punct	40:punct	_
# 25	cuya	cuyo	PRON	pr0fs000	Gender=Fem|Number=Sing|Poss=Yes|PronType=Int,Rel	26	nmod	26:nmod	Entity=(CESSCASTAA200008063784c22-organization-2-gstype:spec(CESSCASTAA200008063784c24-person-1-CorefType:ident,gstype:spec)
# 26	formación	formación	NOUN	ncfs000	Gender=Fem|Number=Sing	40	nsubj	40:nsubj	SpaceAfter=No
# 27	,	,	PUNCT	fc	PunctType=Comm	29	punct	29:punct	Entity=(CESSCASTAA200008063784c22-organization-3-CorefType:pred.definit,gstype:spec
# 28	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	29	det	29:det	_
# 29	Partido	Partido	PROPN	np00000	_	26	appos	26:appos	MWE=Partido_Demócrata_de_Indonesia_para_la_Lucha|MWEPOS=PROPN
# 30	Demócrata	Demócrata	PROPN	_	_	29	flat	29:flat	_
# 31	de	de	ADP	_	_	32	case	32:case	_
# 32	Indonesia	Indonesia	PROPN	_	_	29	flat	29:flat	_
# 33	para	para	ADP	_	_	35	case	35:case	_
# 34	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	35	det	35:det	_
# 35	Lucha	Lucha	PROPN	_	_	29	flat	29:flat	_
# 36	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	37	punct	37:punct	SpaceAfter=No|Entity=(CESSCASTAA200008063784c22-organization-2-CorefType:pred.definit,gstype:spec
# 37	PDIL	PDIL	PROPN	np00000	_	29	flat	29:flat	SpaceAfter=No
# 38	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	37	punct	37:punct	SpaceAfter=No|Entity=CESSCASTAA200008063784c22)
# 39	,	,	PUNCT	fc	PunctType=Comm	29	punct	29:punct	Entity=CESSCASTAA200008063784c22)CESSCASTAA200008063784c22)
# 40	obtuvo	obtener	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	22	acl	22:acl	_
# 41	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	42	det	42:det	Entity=(CESSCASTAA200008063784s14.sn.59--2-gstype:gen
# 42	victoria	victoria	NOUN	ncfs000	Gender=Fem|Number=Sing	40	obj	40:obj	Entity=CESSCASTAA200008063784s14.sn.59)
# 43	en	en	ADP	sps00	_	45	case	45:case	_
# 44	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	45	det	45:det	Entity=(CESSCASTAA200008063784c23--2-CorefType:ident,gstype:gen,HomoDD
# 45	comicios	comicio	NOUN	ncmp000	Gender=Masc|Number=Plur	40	obl	40:obl	_
# 46	legislativos	legislativo	ADJ	aq0mp0	Gender=Masc|Number=Plur	45	amod	45:amod	SpaceAfter=No|Entity=CESSCASTAA200008063784c23)CESSCASTAA200008063784c24)
# 47	.	.	PUNCT	fp	PunctType=Peri	16	punct	16:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000806-3784-s15
# # text = El PKB obtuvo el cuarto puesto en las elecciones generales, y para evitar no despertar las iras del PDIL, Megawati, hija del primer presidente de Indonesia, Sukarno, fue elegida vicepresidenta.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200008063784c21-organization-2-CorefType:ident,gstype:spec
# 2	PKB	PKB	PROPN	np00000	_	3	nsubj	3:nsubj	Entity=CESSCASTAA200008063784c21)
# 3	obtuvo	obtener	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 4	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	Entity=(CESSCASTAA200008063784s15.sn.10--3-gstype:gen,HomoDD
# 5	cuarto	cuarto	ADJ	ao0ms0	Gender=Masc|Number=Sing|NumType=Ord	6	amod	6:amod	_
# 6	puesto	puesto	NOUN	ncms000	Gender=Masc|Number=Sing	3	obj	3:obj	Entity=CESSCASTAA200008063784s15.sn.10)
# 7	en	en	ADP	sps00	_	9	case	9:case	_
# 8	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	9	det	9:det	Entity=(CESSCASTAA200008063784c23--2-CorefType:ident,gstype:gen,HomoDD
# 9	elecciones	elección	NOUN	ncfp000	Gender=Fem|Number=Plur	3	obl	3:obl	_
# 10	generales	general	ADJ	aq0cp0	Number=Plur	9	amod	9:amod	SpaceAfter=No|Entity=CESSCASTAA200008063784c23)
# 11	,	,	PUNCT	fc	PunctType=Comm	36	punct	36:punct	_
# 12	y	y	CCONJ	cc	_	36	cc	36:cc	_
# 13	para	para	ADP	sps00	_	14	mark	14:mark	_
# 14	evitar	evitar	VERB	vmn0000	VerbForm=Inf	36	advcl	36:advcl	_
# 15	no	no	ADV	rn	Polarity=Neg	14	advmod	14:advmod	_
# 16	despertar	despertar	VERB	vmn0000	VerbForm=Inf	14	xcomp	14:xcomp	_
# 17	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	18	det	18:det	_
# 18	iras	ira	NOUN	ncfp000	Gender=Fem|Number=Plur	16	obj	16:obj	_
# 19-20	del	_	_	_	_	_	_	_	_
# 19	de	de	ADP	spcms	_	21	case	21:case	_
# 20	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	21	det	21:det	_
# 21	PDIL	PDIL	PROPN	np00000	_	18	nmod	18:nmod	SpaceAfter=No|Entity=(CESSCASTAA200008063784c22-organization-1-CorefType:ident,gstype:spec)
# 22	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	_
# 23	Megawati	Megawati	PROPN	np00000	_	36	nsubj	36:nsubj	SpaceAfter=No|Entity=(CESSCASTAA200008063784c24-person-1-CorefType:ident,gstype:spec
# 24	,	,	PUNCT	fc	PunctType=Comm	25	punct	25:punct	Entity=(CESSCASTAA200008063784c24-person-2-CorefType:pred.definit,gstype:spec
# 25	hija	hija	NOUN	ncfs000	Gender=Fem|Number=Sing	23	appos	23:appos	_
# 26-27	del	_	_	_	_	_	_	_	_
# 26	de	de	ADP	spcms	_	29	case	29:case	_
# 27	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	29	det	29:det	_
# 28	primer	primero	ADJ	ao0ms0	Gender=Masc|Number=Sing|NumType=Ord	29	amod	29:amod	Entity=(CESSCASTAA200008063784c25-person-2-gstype:spec
# 29	presidente	presidente	NOUN	ncms000	Gender=Masc|Number=Sing	25	nmod	25:nmod	_
# 30	de	de	ADP	sps00	_	31	case	31:case	_
# 31	Indonesia	Indonesia	PROPN	np00000	_	29	nmod	29:nmod	SpaceAfter=No|Entity=(CESSCASTAA200008063784c26-place-1-CorefType:ident,gstype:spec)
# 32	,	,	PUNCT	fc	PunctType=Comm	33	punct	33:punct	Entity=(CESSCASTAA200008063784c25-person-2-CorefType:pred.definit,gstype:spec
# 33	Sukarno	Sukarno	PROPN	np00000	_	29	appos	29:appos	SpaceAfter=No
# 34	,	,	PUNCT	fc	PunctType=Comm	33	punct	33:punct	Entity=CESSCASTAA200008063784c25)CESSCASTAA200008063784c25)CESSCASTAA200008063784c24)CESSCASTAA200008063784c24)
# 35	fue	ser	AUX	vsis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	36	aux	36:aux	_
# 36	elegida	elegir	VERB	vmp00sf	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	3	conj	3:conj	_
# 37	vicepresidenta	vicepresidenta	NOUN	ncfs000	Gender=Fem|Number=Sing	36	obj	36:obj	SpaceAfter=No
# 38	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
#
#
# # global.Entity = eid-etype-head-other
# # newdoc id = CESS-CAST-AA-20000923-19559
# # sent_id = CESS-CAST-AA-20000923-19559-s1
# # text = El presidente de la Junta de Extremadura, Juan Carlos Rodríguez Ibarra, cree que si el Gobierno vasco no cumple las competencias asignadas en materia de seguridad pública "alguien debería quitárselas".
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA2000092319559c1-person-2-gstype:spec
# 2	presidente	presidente	NOUN	ncms000	Gender=Masc|Number=Sing	14	nsubj	14:nsubj	_
# 3	de	de	ADP	sps00	_	5	case	5:case	_
# 4	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	5:det	Entity=(CESSCASTAA2000092319559c31-organization-2-gstype:spec
# 5	Junta	Junta	PROPN	np00000	_	2	nmod	2:nmod	MWE=Junta_de_Extremadura|MWEPOS=PROPN
# 6	de	de	ADP	_	_	7	case	7:case	_
# 7	Extremadura	Extremadura	PROPN	_	_	5	flat	5:flat	SpaceAfter=No|Entity=CESSCASTAA2000092319559c31)
# 8	,	,	PUNCT	fc	PunctType=Comm	9	punct	9:punct	Entity=(CESSCASTAA2000092319559c1-person-2-CorefType:pred.definit,gstype:spec
# 9	Juan	Juan	PROPN	np00000	_	2	appos	2:appos	MWE=Juan_Carlos_Rodríguez_Ibarra|MWEPOS=PROPN
# 10	Carlos	Carlos	PROPN	_	_	9	flat	9:flat	_
# 11	Rodríguez	Rodríguez	PROPN	_	_	9	flat	9:flat	_
# 12	Ibarra	Ibarra	PROPN	_	_	9	flat	9:flat	SpaceAfter=No
# 13	,	,	PUNCT	fc	PunctType=Comm	9	punct	9:punct	Entity=CESSCASTAA2000092319559c1)CESSCASTAA2000092319559c1)
# 14	cree	creer	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 15	que	que	SCONJ	cs	_	33	mark	33:mark	Entity=(CESSCASTAA2000092319559c2--19
# 16	si	si	SCONJ	cs	_	21	mark	21:mark	_
# 17	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	18	det	18:det	Entity=(CESSCASTAA2000092319559s1.sn.28-organization-2-gstype:spec
# 18	Gobierno	Gobierno	PROPN	np00000	_	21	nsubj	21:nsubj	_
# 19	vasco	vasco	ADJ	aq0ms0	Gender=Masc|Number=Sing	18	amod	18:amod	Entity=CESSCASTAA2000092319559s1.sn.28)
# 20	no	no	ADV	rn	Polarity=Neg	21	advmod	21:advmod	_
# 21	cumple	cumplir	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	33	advcl	33:advcl	_
# 22	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	23	det	23:det	Entity=(CESSCASTAA2000092319559s1.sn.40--2-gstype:gen,HomoDD
# 23	competencias	competencia	NOUN	ncfp000	Gender=Fem|Number=Plur	21	obj	21:obj	_
# 24	asignadas	asignado	ADJ	aq0fpp	Gender=Fem|Number=Plur|VerbForm=Part	23	amod	23:amod	_
# 25	en	en	ADP	sps00	_	28	case	28:case	MWE=en_materia_de|MWEPOS=ADP
# 26	materia	materia	NOUN	_	_	25	fixed	25:fixed	_
# 27	de	de	ADP	_	_	25	fixed	25:fixed	_
# 28	seguridad	seguridad	NOUN	ncfs000	Gender=Fem|Number=Sing	23	nmod	23:nmod	Entity=(CESSCASTAA2000092319559s1.sn.51--1-gstype:gen
# 29	pública	público	ADJ	aq0fs0	Gender=Fem|Number=Sing	28	amod	28:amod	Entity=CESSCASTAA2000092319559s1.sn.51)CESSCASTAA2000092319559s1.sn.40)
# 30	"	"	PUNCT	fe	PunctType=Quot	33	punct	33:punct	SpaceAfter=No
# 31	alguien	alguien	PRON	pi0cs000	Number=Sing|PronType=Ind	33	nsubj	33:nsubj	Entity=(CESSCASTAA2000092319559s1.sn.58--1-gstype:gen)
# 32	debería	deber	AUX	vmic3s0	Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin	33	aux	33:aux	_
# 33-35	quitárselas	_	_	_	_	_	_	_	SpaceAfter=No
# 33	quitar	quitar	VERB	vmn0000	VerbForm=Inf	14	xcomp	14:xcomp	_
# 34	se	él	PRON	_	Case=Dat|Person=3|PrepCase=Npr|PronType=Prs	33	iobj	33:iobj	_
# 35	las	él	PRON	_	Case=Acc|Gender=Fem|Number=Plur|Person=3|PrepCase=Npr|PronType=Prs	33	iobj	33:iobj	_
# 36	"	"	PUNCT	fe	PunctType=Quot	33	punct	33:punct	SpaceAfter=No|Entity=CESSCASTAA2000092319559c2)
# 37	.	.	PUNCT	fp	PunctType=Peri	14	punct	14:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000923-19559-s2
# # text = Rodríguez Ibarra dijo esto en un discurso pronunciado esta noche en Madrid tras recibir el Premio "Encina de Oro", que le otorgó la Federación de Asociaciones Extremeñas de la Comunidad de Madrid.
# 1	Rodríguez	Rodríguez	PROPN	np00000	_	3	nsubj	3:nsubj	MWE=Rodríguez_Ibarra|MWEPOS=PROPN|Entity=(CESSCASTAA2000092319559c1-person-1-CorefType:ident,gstype:spec
# 2	Ibarra	Ibarra	PROPN	_	_	1	flat	1:flat	Entity=CESSCASTAA2000092319559c1)
# 3	dijo	decir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 4	esto	este	PRON	pd0ns000	Number=Sing|PronType=Dem	3	obj	3:obj	Entity=(CESSCASTAA2000092319559c2--1-CorefType:dx.prop)
# 5	en	en	ADP	sps00	_	7	case	7:case	_
# 6	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	7	det	7:det	Entity=(CESSCASTAA2000092319559s2.sn.13--2-gstype:gen
# 7	discurso	discurso	NOUN	ncms000	Gender=Masc|Number=Sing	3	obl	3:obl	_
# 8	pronunciado	pronunciado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	7	amod	7:amod	_
# 9	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	10	det	10:det	Entity=(CESSCASTAA2000092319559s2.sn.21--2-gstype:gen
# 10	noche	noche	NOUN	ncfs000	Gender=Fem|Number=Sing	8	obl	8:obl	Entity=CESSCASTAA2000092319559s2.sn.21)
# 11	en	en	ADP	sps00	_	12	case	12:case	_
# 12	Madrid	Madrid	PROPN	np00000	_	8	obl	8:obl	Entity=(CESSCASTAA2000092319559c15-place-1-gstype:spec)
# 13	tras	tras	ADP	sps00	_	14	mark	14:mark	_
# 14	recibir	recibir	VERB	vmn0000	VerbForm=Inf	8	advcl	8:advcl	_
# 15	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	16	det	16:det	Entity=(CESSCASTAA2000092319559c3-other-2-gstype:spec
# 16	Premio	Premio	PROPN	np00000	_	14	obj	14:obj	_
# 17	"	"	PUNCT	fe	PunctType=Quot	18	punct	18:punct	SpaceAfter=No|Entity=(CESSCASTAA2000092319559s2.sn.43-other-2-gstype:spec
# 18	Encina	Encina	PROPN	np00000	_	16	flat	16:flat	MWE=Encina_de_Oro|MWEPOS=PROPN
# 19	de	de	ADP	_	_	20	case	20:case	_
# 20	Oro	Oro	PROPN	_	_	18	flat	18:flat	SpaceAfter=No
# 21	"	"	PUNCT	fe	PunctType=Quot	18	punct	18:punct	SpaceAfter=No|Entity=CESSCASTAA2000092319559s2.sn.43)
# 22	,	,	PUNCT	fc	PunctType=Comm	25	punct	25:punct	_
# 23	que	que	PRON	pr0cn000	PronType=Int,Rel	25	obj	25:obj	Entity=(CESSCASTAA2000092319559c3-other-1-CorefType:ident,gstype:spec)
# 24	le	él	PRON	pp3csd00	Case=Dat|Number=Sing|Person=3|PronType=Prs	25	obj	25:obj	Entity=(CESSCASTAA2000092319559c1-person-1-CorefType:ident,gstype:spec)
# 25	otorgó	otorgar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	16	acl	16:acl	_
# 26	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	27	det	27:det	Entity=(CESSCASTAA2000092319559s2.sn.57-organization-2-gstype:spec
# 27	Federación	Federación	PROPN	np00000	_	25	nsubj	25:nsubj	MWE=Federación_de_Asociaciones_Extremeñas_de_la_Comunidad_de_Madrid|MWEPOS=PROPN
# 28	de	de	ADP	_	_	29	case	29:case	_
# 29	Asociaciones	Asociaciones	PROPN	_	_	27	flat	27:flat	_
# 30	Extremeñas	Extremeñas	PROPN	_	_	29	flat	29:flat	_
# 31	de	de	ADP	_	_	33	case	33:case	_
# 32	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	33	det	33:det	_
# 33	Comunidad	Comunidad	PROPN	_	_	29	flat	29:flat	_
# 34	de	de	ADP	_	_	35	case	35:case	_
# 35	Madrid	Madrid	PROPN	_	_	29	flat	29:flat	SpaceAfter=No|Entity=CESSCASTAA2000092319559s2.sn.57)CESSCASTAA2000092319559c3)CESSCASTAA2000092319559s2.sn.13)
# 36	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#@title Structure Corpur's Tagged Tokens - Checking on One Token
tokenlist[1]
# Out:
# {'id': 2,
#  'form': 'El',
#  'lemma': 'el',
#  'upos': 'DET',
#  'xpos': 'da0ms0',
#  'feats': {'Definite': 'Def',
#   'Gender': 'Masc',
#   'Number': 'Sing',
#   'PronType': 'Art'},
#  'head': 5,
#  'deprel': 'det',
#  'deps': [('det', 5)],
#  'misc': {'Entity': '(CESSCASTP2002080117s20.sn.3--1-gstype:gen'}}

# %%
# Retrieving Work & Grammatical Category on Previos Token
tokenlist[1]['form']+'|'+tokenlist[1]['upos']
# Out:
# 'El|DET'

# %% [markdown]
# ## Model Training - Counting Calculation:
#
# * Tags (tags) `tagCountDict`: $C(tag)$
# * Emisions (word|tag) `emissionProbDict`: $C(word|tag)$
# * Transitions (tag|prevtag) `transitionDict`: $C(tag|prevtag)$

# %%
tagCountDict = {} 
emissionDict = {}
transitionDict = {}

tagtype = 'upos'
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

# Counting Calculation (pre-probabilities)
for tokenlist in parse_incr(data_file):
  prevtag = None
  for token in tokenlist:

    # C(tag)
    tag = token[tagtype]
    if tag in tagCountDict.keys():
      tagCountDict[tag] += 1
    else:
      tagCountDict[tag] = 1

    # C(word|tag) -> Emision probabilities
    wordtag = token['form'].lower()+'|'+token[tagtype] # (word|tag)
    if wordtag in emissionDict.keys():
      emissionDict[wordtag] = emissionDict[wordtag] + 1
    else:
      emissionDict[wordtag] = 1

    #  C(tag|previous_tag) ->  Transition Probabilities
    if prevtag is None:
      prevtag = tag
      continue
    transitiontags = tag+'|'+prevtag
    if transitiontags in transitionDict.keys():
      transitionDict[transitiontags] = transitionDict[transitiontags] + 1
    else:
      transitionDict[transitiontags] = 1
    prevtag = tag
    
#transitionDict
#emissionDict
#tagCountDict

# %% [markdown]
# ## Model Training - Probabilities Calculus
# * Trasitional Probabilities:
# $$P(tag|prevtag) = \frac{C(prevtag, tag)}{C(prevtag)}$$
#
# * Emission Probabilities:
#  $$P(word|tag) = \frac{C(word|tag)}{C(tag)}$$

# %%
transitionProbDict = {} # matriz A
emissionProbDict = {} # matriz B

# Transition Probabilities 
for key in transitionDict.keys():
  tag, prevtag = key.split('|')
  if tagCountDict[prevtag]>0:
    transitionProbDict[key] = transitionDict[key]/(tagCountDict[prevtag])
  else:
    print(key)

# Emission Probabilities 
for key in emissionDict.keys():
  word, tag = key.split('|')
  if emissionDict[key]>0:
    emissionProbDict[key] = emissionDict[key]/tagCountDict[tag]
  else:
    print(key)

transitionProbDict['ADJ|ADJ']
#emissionProbDict
# Out:
# 0.030217452696978255

# %% [markdown]
# ## Saving Model Paramenters

# %%
import numpy as np
np.save('transitionHMM.npy', transitionProbDict)
np.save('emissionHMM.npy', emissionProbDict)
transitionProbdict = np.load('transitionHMM.npy', allow_pickle='TRUE').item()
transitionProbDict['ADJ|ADJ']
# Out:
# 0.030217452696978255
